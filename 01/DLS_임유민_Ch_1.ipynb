# %% [markdown]
# # Deep Learning from scratch
# ### chapter 1

# %% [markdown]
# *   *산술연산*

# %%
print(1-2)
print(4*5)
print(7/5)
print(3**2)
# Out:
# -1
# 20
# 1.4
# 9

# %% [markdown]
# *   자료형

# %%
type(10) # int
type(2.718) #float
type("hello") #string
# Out:
# str

# %% [markdown]
# *   변수

# %%
x =10 # 초기화
print(x)

x = 100
print(x)

y = 3.14
print(x*y)

type(x*y)
# Out:
# 10
# 100
# 314.0
# float

# %% [markdown]
# *  리스트

# %%
a = [1,2,3,4,5]
print(a)

len(a)

a[0]

a[4]

a[4] = 99

print(a)
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4, 99]

# %%
# 슬라이싱
print(a)
a[0:2] # 인덱스 0 ~ 1까지
a[1:2] # 인덱스 1부터 끝까지
a[:3] # 인덱스 처음부터 2까지
a[:-1] # 처음부터 마지막원소 인덱스 -1 까지 얻기
a[:-2] # 처음부터 마지막원소 인덱스 -2 까지 얻기
# Out:
# [1, 2, 3, 4, 99]
# [1, 2, 3]

# %% [markdown]
# *  딕셔너리

# %%
me = {'height':180} # 딕셔너리 생성
me['height'] # 원소 접근
me['weight'] = 70 # 추가
print(me)
# Out:
# {'height': 180, 'weight': 70}

# %% [markdown]
# *  bool

# %%
hungry = True
sleepy = False
type(hungry) # class -> bool
not hungry # False
hungry and sleepy # False
hungry or sleepy # True
# Out:
# True

# %% [markdown]
# *  if 문

# %%
hungry = True
if hungry:
  print("I'm hungry")

hungry = False
if hungry:
  print("I'm hungry")   # 들여쓰기는 공백 문자로
else:
  print("I'm not hungry")
  print("I'm sleepy")
# Out:
# I'm hungry
# I'm not hungry
# I'm sleepy

# %% [markdown]
# *  for 문

# %%
for i in[1, 2, 3]:
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# *  함수

# %%
def hello():
  print("Hello World!")

hello()
# Out:
# Hello World!

# %%
def hello(object):
  print("Hello " + object + "!")

hello("cat")
# Out:
# Hello cat!

# %% [markdown]
# *  클래스

# %%
class Man:
    def __init__(self, name):
        self.name = name
        print("Initialized!")

    def hello(self):
        print("Hello " + self.name + "!")

    def goodbye(self):
        print("Good-bye " + self.name + "!")

m = Man("David")
m.hello()
m.goodbye()
# Out:
# Initialized!
# Hello David!
# Good-bye David!

# %% [markdown]
# *  넘파이 가져오기

# %%
import numpy as np

# %% [markdown]
# *  넘파이 배열 생성하기

# %%
x = np.array([1.0, 2.0, 3.0])
print(x)
type(x)
# Out:
# [1. 2. 3.]
# numpy.ndarray

# %% [markdown]
# *  넘파이 산술연산

# %%
x = np.array([1.0, 2.0, 3.0])
y = np.array([2.0, 4.0, 6.0])
x + y # 원소별 덧셈 -> array([ 3., 6., 9.])
x - y # 뺄셈 -> array([ -1., -2., -3.])
x * y # 원소별 곱셈 -> array([ 2., 8., 18.])
x / y # 나눗셈 ->  array([ 0.5, 0.5, 0.5])
# Out:
# array([0.5, 0.5, 0.5])

# %% [markdown]
# *  넘파이의 n차원 차원 배열

# %%
A = np.array([[1, 2], [3, 4]])
print(A)
A.shape # -> (2,2)
A.dtype
# Out:
# [[1 2]
#  [3 4]]
# dtype('int64')

# %%
B = np.array([[3, 0], [0, 6]])
A + B # ->array([[ 4, 2],[ 3, 10]])
A * B # ->array([[ 3, 0],[ 0, 24]])
# Out:
# array([[ 3,  0],
#        [ 0, 24]])

# %%
# 배열 스칼라 값 산술 연산
print(A)
A * 10
# Out:
# [[1 2]
#  [3 4]]
# array([[10, 20],
#        [30, 40]])

# %% [markdown]
# *  브로드캐스트
#     *   [[1, 2], [3, 4]] * 10 을 [[1, 2], [3, 4]] x [[10 10],[10, 10]] 로 바꾸어 연산하는 것을 브로드 캐스트라함

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([10, 20])
A * B
# Out:
# array([[10, 40],
#        [30, 80]])

# %% [markdown]
# *  원소

# %%
X = np.array([[51, 55], [14, 19], [0, 4]])
print(X)
X[0]     # 0행 -> arrary([51, 55])
X[0][1]  # (0, 1) 위치의 원소
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]
# 55

# %%
# for 문으로 원소 접근
for row in X:
  print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %%
# X를 1차원 배열로 변환(평탄화)
X = X.flatten()
print(X)

# 인덱스가 0, 2, 4인 원소 얻기
X[np.array([0, 2, 4])]
# Out:
# [51 55 14 19  0  4]
# array([51, 14,  0])

# %%
# bool 배열
X > 15
# Out:
# array([ True,  True, False,  True, False, False])

# %%
# bool 배열로 배열의 값을 추출
X[X>15]
# Out:
# array([51, 55, 19])

# %% [markdown]
# *  matplotlib 단순한 그래프 그리기

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1) # 0에서 6까지 0.1 간격으로 생성
y = np.sin(x) # y 값은 sin(x)

# 그래프 그리기
plt.plot(x, y)
plt.show()

# %% [markdown]
# *  pyplot의 기능

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1) # 0에서 6까지 0.1 간격으로 생성
y1 = np.sin(x)
y2 = np.cos(x)

# 그래프 그리기
plt.plot(x, y1, label="sin")
plt.plot(x, y2, linestyle = "--", label="cos") # cos 함수는 점선으로 그리기
plt.xlabel("x")        # x축 이름
plt.ylabel("y")        # y축 이름
plt.title('sin & cos') # 그래프 제목
plt.legend() # 범례 생성
plt.show()

# %% [markdown]
# *  이미지 표시하기

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('/content/cactus.JPG') # 이미지 읽어오기

plt.imshow(img)
plt.show()
